# %%
# data---> x,y

#x--> x_train , x_test
#y--> y_train  ,  y_test

#for model training
# model.fit(x_train, y_train)


#for model predection
# y_pred= model.predict(x_test)
#model Accuracy
#metrics_score(y_test, y_pred)

# %%
#Model-->
#1. Supervisor ML model--> Labeled data train--> LinerRegression , LogisticRegression,
# Decision tree, RandomForest etc.

#2. Insupervised ML model--> Unlabeled data train--> Kmeans, PCA

# %% [markdown]
# # LinerRegression

# %%
# numerical data --->continous data

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"D:\Python\Data set\insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['sex']=lb.fit_transform(df['sex'])
df['smoker']=lb.fit_transform(df['smoker'])
df['region']=lb.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7833463107364539

# %% [markdown]
# # Logistic Regression

# %%
#LogisticRegression Model-->When we have categorical column.

# Backend---> Activation function(Data ko scaled formet me leakr aana)-->Sigmoid--> Probability basis
# Probability (0-1)
# Threshold_value= 0.5 or 1/2
# if 0.5 > value
#    return 1
# else:
#    return 0

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"D:\Python\Data set\covid_toy.csv")
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['gender']=lb.fit_transform(df['gender'])
df['cough']=lb.fit_transform(df['cough'])
df['city']=lb.fit_transform(df['city'])
df['has_covid']=lb.fit_transform(df['has_covid'])

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df['fever']=si.fit_transform(df[['fever']])

# %%
x=df.drop(columns=['has_covid'])
y=df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train ,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score  # Accuracy_score--> for categorigal data

# %%
accuracy_score(y_test ,y_pred)
# Out:
# 0.75

# %% [markdown]
# # Dataset -Placement

# %%
df=pd.read_csv(r"D:\Python\Data set\placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
x=df.drop(columns=['placed'])
y=df['placed']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train ,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
accuracy_score(y_test ,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)  #overfitting
# Out:
# 1.0

# %%
# difference between overfitting and underfitting
# what is bias variance trade of 
#
